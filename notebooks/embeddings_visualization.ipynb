# %% [markdown]
# # Setup

# %%
import os
if os.getcwd().endswith('notebooks'):
    os.chdir('..')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import seaborn as sns
import umap

# %%
sns.set()

# %% [markdown]
# # Loading Data

# %%
embeddings = np.load('data/outputs/embeddings.npy')
embeddings.shape
# Out:
# (122, 128)

# %%
hero_names = pd.read_csv('data/outputs/heronames.tsv', sep='\t', header=None).iloc[:, 0]
hero_names.head()
# Out:
# 0         unused
# 1      Anti-Mage
# 2            Axe
# 3           Bane
# 4    Bloodseeker
# Name: 0, dtype: object

# %% [markdown]
# # Plotting

# %%
def plot_embeddings(embs_2d):
    fig, ax = plt.subplots(figsize=(15, 15))
    mpl.scatter(embs_2d[:, 0], embs_2d[:, 1], s=15, alpha=0.9, marker='o')
    for i, name in enumerate(hero_names):
        ax.annotate(name, (embs_2d[i, 0], embs_2d[i, 1]))
    return ax

# %% [markdown]
# # PCA

# %%
pca_embeddings = PCA(2).fit_transform(embeddings)

# %%
plot_embeddings(pca_embeddings)

# %% [markdown]
# # t-SNE

# %%
tsne_embeddings = TSNE(2, perplexity=10).fit_transform(embeddings)

# %%
plot_embeddings(tsne_embeddings)

# %% [markdown]
# # UMAP

# %%
umap_embeddings = umap.UMAP().fit_transform(embeddings)

# %%
plot_embeddings(umap_embeddings)
